# %%
import pandas as pd
df = pd.read_csv('data/matriculaciones_educacion_escolar_basica_2020.csv', index_col=0)

# %%
df.head()
# Out:
#       codigo_establecimiento  codigo_departamento nombre_departamento  \
# anio
# 2020                 1701005                   17       Alto Paraguay
# 2020                 1701014                   17       Alto Paraguay
# 2020                 1701007                   17       Alto Paraguay
# 2020                 1701005                   17       Alto Paraguay
# 2020                 1701006                   17       Alto Paraguay
#
#       codigo_distrito nombre_distrito  codigo_zona nombre_zona  \
# anio
# 2020                4     Bahía Negra            1      Urbana
# 2020                4     Bahía Negra            2       Rural
# 2020                4     Bahía Negra            2       Rural
# 2020                4     Bahía Negra            1      Urbana
# 2020                4     Bahía Negra            1      Urbana
#
#      codigo_barrio_localidad           nombre_barrio_localidad  \
# anio
# 2020                    8984                           CENTRAL
# ...
